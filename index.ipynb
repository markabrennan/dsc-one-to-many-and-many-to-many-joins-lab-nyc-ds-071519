# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
import sqlite3 
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
import pandas as pd

c.execute("""select e.firstName, e.lastName, o.city, o.state
from employees e
join offices o
using(officeCode)
order by firstName, lastName;""")
df = pd.DataFrame(c.fetchall())
df
# Out:
#            0          1              2           3
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
import pandas as pd

c.execute("""select contactFirstName, contactLastName, orderNumber, orderDate, status
from customers
join orders
using (customerNumber);""")
df = pd.DataFrame(c.fetchall())
df
# Out:
#                0           1      2           3           4
# 0        Carine      Schmitt  10123  2003-05-20     Shipped
# 1        Carine      Schmitt  10298  2004-09-27     Shipped
# 2        Carine      Schmitt  10345  2004-11-25     Shipped
# 3           Jean        King  10124  2003-05-21     Shipped
# 4           Jean        King  10278  2004-08-06     Shipped
# 5           Jean        King  10346  2004-11-29     Shipped
# 6          Peter    Ferguson  10120  2003-04-29     Shipped
# 7          Peter    Ferguson  10125  2003-05-21     Shipped
# 8          Peter    Ferguson  10223  2004-02-20     Shipped
# 9          Peter    Ferguson  10342  2004-11-24     Shipped
# 10         Peter    Ferguson  10347  2004-11-29     Shipped
# 11       Janine      Labrune  10275  2004-07-23     Shipped
# 12       Janine      Labrune  10315  2004-10-29     Shipped
# 13       Janine      Labrune  10375  2005-02-03     Shipped
# 14       Janine      Labrune  10425  2005-05-31  In Process
# 15        Jonas   Bergulfsen  10103  2003-01-29     Shipped
# 16        Jonas   Bergulfsen  10158  2003-10-10     Shipped
# 17        Jonas   Bergulfsen  10309  2004-10-15     Shipped
# 18        Jonas   Bergulfsen  10325  2004-11-05     Shipped
# 19         Susan      Nelson  10113  2003-03-26     Shipped
# 20         Susan      Nelson  10135  2003-07-02     Shipped
# 21         Susan      Nelson  10142  2003-08-08     Shipped
# 22         Susan      Nelson  10182  2003-11-12     Shipped
# 23         Susan      Nelson  10229  2004-03-11     Shipped
# 24         Susan      Nelson  10271  2004-07-20     Shipped
# 25         Susan      Nelson  10282  2004-08-20     Shipped
# 26         Susan      Nelson  10312  2004-10-21     Shipped
# 27         Susan      Nelson  10335  2004-11-19     Shipped
# 28         Susan      Nelson  10357  2004-12-10     Shipped
# 29         Susan      Nelson  10368  2005-01-19     Shipped
# ..           ...         ...    ...         ...         ...
# 296           Yu        Choi  10242  2004-04-20     Shipped
# 297           Yu        Choi  10319  2004-11-03     Shipped
# 298      Martín       Sommer  10126  2003-05-28     Shipped
# 299      Martín       Sommer  10214  2004-01-26     Shipped
# 300      Martín       Sommer  10348  2004-11-01     Shipped
# 301      Violeta     Benitez  10166  2003-10-21     Shipped
# 302      Violeta     Benitez  10321  2004-11-04     Shipped
# 303      Violeta     Benitez  10388  2005-03-03     Shipped
# 304         Sean    Clenahan  10193  2003-11-21     Shipped
# 305         Sean    Clenahan  10265  2004-07-02     Shipped
# 306         Sean    Clenahan  10415  2005-05-09    Disputed
# 307       Franco     Ricotti  10157  2003-10-09     Shipped
# 308       Franco     Ricotti  10218  2004-02-09     Shipped
# 309        Steve    Thompson  10199  2003-12-01     Shipped
# 310        Steve    Thompson  10215  2004-01-29     Shipped
# 311  José Pedro         Roel  10184  2003-11-14     Shipped
# 312  José Pedro         Roel  10303  2004-10-06     Shipped
# 313         Rosa     Salazar  10109  2003-03-10     Shipped
# 314         Rosa     Salazar  10236  2004-04-03     Shipped
# 315         Rosa     Salazar  10331  2004-11-17     Shipped
# 316          Sue      Taylor  10149  2003-09-12     Shipped
# 317          Sue      Taylor  10219  2004-02-10     Shipped
# 318      Thomas        Smith  10186  2003-11-14     Shipped
# 319      Thomas        Smith  10213  2004-01-22     Shipped
# 320      Valarie      Franco  10207  2003-12-09     Shipped
# 321      Valarie      Franco  10243  2004-04-26     Shipped
# 322         Tony     Snowden  10138  2003-07-07     Shipped
# 323         Tony     Snowden  10179  2003-11-11   Cancelled
# 324         Tony     Snowden  10360  2004-12-16     Shipped
# 325         Tony     Snowden  10399  2005-04-01     Shipped
#
# [326 rows x 5 columns]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
import pandas as pd

c.execute("""select contactFirstName, contactLastName, amount
from customers
join payments
using(customerNumber)
order by amount DESC ;""")
df = pd.DataFrame(c.fetchall())
df
# Out:
#               0           1          2
# 0       Violeta     Benitez    9977.85
# 1           Ben    Calaghan    9821.32
# 2        Leslie      Taylor    9658.74
# 3          Sean    Clenahan    9415.13
# 4       Roland       Mendel    8807.12
# 5         Julie       Brown   85559.12
# 6         Susan      Nelson   85410.87
# 7        Veysel      Oeztan   85024.46
# 8         Susan      Nelson   83598.04
# 9          Wing       Huang    8307.28
# 10        Peter    Ferguson   82261.22
# 11      Valarie    Thompson   80375.24
# 12        Steve    Thompson    7678.25
# 13   Christina     Berglund    7674.94
# 14       Franco     Ricotti    7612.06
# 15        Peter    Ferguson    7565.08
# 16         Mike      Graham   75020.13
# 17       Roland      Keitel    7466.32
# 18      Thomas        Smith    7310.42
# 19      William       Brown    7178.66
# 20          Dan       Lewis    6631.36
# 21       Diego       Freyre   65071.26
# 22       Georg        Pipps    6419.84
# 23       Diego       Freyre   63843.55
# 24       Kelvin       Leong   63357.13
# 25      Valarie      Franco    6276.60
# 26        Akiko   Shimamura     615.45
# 27       Mihael        Holz   61402.00
# 28   Henriette    Pfalzheim   61234.67
# 29      Carine      Schmitt    6066.78
# ..          ...         ...        ...
# 243      Pirkko   Koskitalo   16212.59
# 244      Arnold        Cruz   15822.84
# 245       Jesus   Fernandez   15322.93
# 246        Mory     Kentary   15183.63
# 247     Roland       Mendel   15130.97
# 248        Juri     Yoshido   15059.76
# 249      Jonas   Bergulfsen    1491.38
# 250     Carine      Schmitt   14571.44
# 251    Pascale     Cartrain   14379.90
# 252    Annette       Roulet   14232.70
# 253        Jean        King   14191.12
# 254       Paul      Henriot   13920.26
# 255        Ann        Brown   13671.82
# 256        Juri   Hashimoto   12692.19
# 257         Sue      Taylor   12573.28
# 258      Veysel      Oeztan   12538.01
# 259       Allen      Nelson   12530.51
# 260    Annette       Roulet   12432.32
# 261   Dominique     Perrier   12190.85
# 262    Pascale     Cartrain   12081.52
# 263      Diego       Freyre  120166.58
# 264       Jerry       Tseng   11843.45
# 265      Diego       Freyre  116208.40
# 266    Pascale     Cartrain    1128.20
# 267       Susan      Nelson  111654.40
# 268       Susan      Nelson   11044.30
# 269        Eric   Natividad  105743.00
# 270      Roland      Keitel   10549.01
# 271     Dorothy       Young   10223.83
# 272       Susan      Nelson  101244.59
#
# [273 rows x 3 columns]

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
import pandas as pd

c.execute("""select contactFirstName, contactLastName, productName, quantityOrdered, orderDate
from customers
join

(select orderNumber, productCode, quantityOrdered, productName, customerNumber, orderDate
from orders
join
    (select orderNumber, productCode, productName, quantityOrdered
    from orderdetails
    join products
    using(productCode))
using(orderNumber))
using(customerNumber)
order by orderDate DESC;""")
df = pd.DataFrame(c.fetchall())
df
# Out:
#                0           1                                            2   3  \
# 0        Janine      Labrune                       1962 LanciaA Delta 16V  38
# 1        Janine      Labrune                            1957 Chevy Pickup  33
# 2        Janine      Labrune               1998 Chrysler Plymouth Prowler  28
# 3        Janine      Labrune                       1964 Mercedes Tour Bus  38
# 4        Janine      Labrune                        1926 Ford Fire Engine  19
# 5        Janine      Labrune                  1992 Ferrari 360 Spider red  28
# 6        Janine      Labrune                             1940s Ford truck  38
# 7        Janine      Labrune                           1970 Dodge Coronet  55
# 8        Janine      Labrune                     1962 Volkswagen Microbus  49
# 9        Janine      Labrune          1958 Chevy Corvette Limited Edition  31
# 10       Janine      Labrune                  1980’s GM Manhattan Express  41
# 11       Janine      Labrune                  1954 Greyhound Scenicruiser  11
# 12       Janine      Labrune             Diamond T620 Semi-Skirted Tanker  18
# 13        Diego       Freyre                     1952 Alpine Renault 1300  50
# 14        Diego       Freyre                               1958 Setra Bus  49
# 15        Diego       Freyre                       1940 Ford Pickup Truck  54
# 16        Diego       Freyre                      1939 Cadillac Limousine  26
# 17        Diego       Freyre  1996 Peterbilt 379 Stake Bed with Outrigger  44
# 18        Diego       Freyre                              1982 Camaro Z28  46
# 19        Kelvin       Leong                         1937 Lincoln Berline  51
# 20        Kelvin       Leong     1936 Mercedes-Benz 500K Special Roadster  25
# 21    Catherine        Dewey                  1913 Ford Model T Speedster  10
# 22    Catherine        Dewey                           1934 Ford V8 Coupe  31
# 23    Catherine        Dewey          18th Century Vintage Horse Carriage  21
# 24    Catherine        Dewey                     1917 Maxwell Touring Car  21
# 25    Catherine        Dewey                        1936 Chrysler Airflow  28
# 26         Susan      Nelson                       1928 Mercedes-Benz SSK  35
# 27         Susan      Nelson    1938 Cadillac V-16 Presidential Limousine  40
# 28        Adrian      Huxley                     1917 Grand Touring Sedan  37
# 29        Adrian      Huxley                           1911 Ford Town Car  36
# ...          ...         ...                                          ...  ..
# 2966      Diego       Freyre                  1954 Greyhound Scenicruiser  35
# 2967      Diego       Freyre       1950's Chicago Surface Lines Streetcar  49
# 2968      Diego       Freyre             Diamond T620 Semi-Skirted Tanker  33
# 2969      Diego       Freyre               1962 City of Detroit Streetcar  32
# 2970      Jonas   Bergulfsen                     1952 Alpine Renault 1300  26
# 2971      Jonas   Bergulfsen                       1962 LanciaA Delta 16V  42
# 2972      Jonas   Bergulfsen                               1958 Setra Bus  27
# 2973      Jonas   Bergulfsen                       1940 Ford Pickup Truck  35
# 2974      Jonas   Bergulfsen                        1926 Ford Fire Engine  22
# 2975      Jonas   Bergulfsen                  1913 Ford Model T Speedster  27
